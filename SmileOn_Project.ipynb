# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
smile = pd.read_csv('SmileOn11.28.2020.csv', engine = 'python', skiprows = 2)
smile.head()
# Out:
#    CallReportNum              ReportVersion  LinkedToCallReportNum  \
# 0       81381827  SMILE ON 60+ Registration                    NaN
# 1       81379177  SMILE ON 60+ Registration                    NaN
# 2       81377435      SMILE ON 60+ Clinical                    NaN
# 3       81375215      SMILE ON 60+ Clinical                    NaN
# 4       81373934      SMILE ON 60+ Clinical                    NaN
#
#   CallDateAndTimeStart CallDateAndTimeEnd  CallLength  CallerNum  \
# 0     11/25/2020 16:46   11/25/2020 16:48           2    3859874
# 1     11/25/2020 15:40   11/25/2020 15:55          15    3859755
# 2     11/25/2020 15:02   11/25/2020 15:02           0    2518680
# 3     11/25/2020 14:17   11/25/2020 14:17           0    3231923
# 4     11/25/2020 13:50   11/25/2020 13:58           8         -1
#
#    PhoneWorkerNum  WasRealCall  WasHangup  WasSexCall  WasWrongNumber  \
# 0          136529          NaN        NaN         NaN             NaN
# ...

# %%
smile.shape
# Out:
# (40032, 184)

# %%
smile.columns
# Out:
# Index(['CallReportNum', 'ReportVersion', 'LinkedToCallReportNum',
#        'CallDateAndTimeStart', 'CallDateAndTimeEnd', 'CallLength', 'CallerNum',
#        'PhoneWorkerNum', 'WasRealCall', 'WasHangup',
#        ...
#        'SMILE ON 60+ Screening - Treatment Urgency',
#        'SMILE ON 60+ Screening - Untreated Decay',
#        'SMILE ON 60+ Site Information - Enroller ID',
#        'SMILE ON 60+ Site Information - Enroller Location',
#        'SMILE ON 60+ Treatment Plan - Action: Upload After Picture on Finish Tab',
#        'SMILE ON 60+ Treatment Plan - Is the treatment plan completed?',
#        'SMILE ON 60+ Treatment Plan - Was a treatment plan developed?',
#        'SMILE ON 60+ Treatment Plan - Was the enrollee able to be restored to function (can chew) and "social six" esthetics (top front six teeth are present and disease free)',
#        'SMILE ON 60+ Verification of Eligibility - Transportation Arranged',
# ...

# %%
smileon = smile[['CallReportNum', 'CallerNum', 'SMILE ON 60+ Screening - Last Screening Date',
                 'SMILE ON 60+ Oral Care Encounter - What care was provided to the enrollee? (Select all that apply)',
                 'SMILE ON 60+ Site Information - Enroller ID',
                 'SMILE ON 60+ Treatment Plan - Is the treatment plan completed?',
                 'SMILE ON 60+ Treatment Plan - Was a treatment plan developed?',
                 'SMILE ON 60+ Treatment Plan - Was the enrollee able to be restored to function (can chew) and "social six" esthetics (top front six teeth are present and disease free)']]

# %%
smileon.columns
# Out:
# Index(['CallReportNum', 'CallerNum',
#        'SMILE ON 60+ Screening - Last Screening Date',
#        'SMILE ON 60+ Oral Care Encounter - What care was provided to the enrollee? (Select all that apply)',
#        'SMILE ON 60+ Site Information - Enroller ID',
#        'SMILE ON 60+ Treatment Plan - Is the treatment plan completed?',
#        'SMILE ON 60+ Treatment Plan - Was a treatment plan developed?',
#        'SMILE ON 60+ Treatment Plan - Was the enrollee able to be restored to function (can chew) and "social six" esthetics (top front six teeth are present and disease free)'],
#       dtype='object')

# %%
smileon.shape
# Out:
# (40032, 8)

# %%
smileon.head()
# Out:
#    CallReportNum  CallerNum SMILE ON 60+ Screening - Last Screening Date  \
# 0       81381827    3859874                                          NaN
# 1       81379177    3859755                                          NaN
# 2       81377435    2518680                                          NaN
# 3       81375215    3231923                                          NaN
# 4       81373934         -1                                   11/25/2020
#
#   SMILE ON 60+ Oral Care Encounter - What care was provided to the enrollee? (Select all that apply)  \
# 0                                                NaN
# 1                                                NaN
# 2  5650 - Add tooth to existing partial denture - 30
# 3  No Code - Denture step Mandibular: may be used...
# 4                                                NaN
#
#          SMILE ON 60+ Site Information - Enroller ID  \
# 0  Matthew Walker Comprehensive Health Center Inc...
# ...

# %%
smileon = smileon.rename(columns = {'SMILE ON 60+ Screening - Last Screening Date': 'Last_Screen_Date',
                 'SMILE ON 60+ Oral Care Encounter - What care was provided to the enrollee? (Select all that apply)': 'Care_Provided',
                 'SMILE ON 60+ Site Information - Enroller ID': 'Enroller_ID',
                 'SMILE ON 60+ Treatment Plan - Is the treatment plan completed?': 'Treatment_Plan_Completed',
                 'SMILE ON 60+ Treatment Plan - Was a treatment plan developed?': 'Treatment_Plan_Developed',
                 'SMILE ON 60+ Treatment Plan - Was the enrollee able to be restored to function (can chew) and "social six" esthetics (top front six teeth are present and disease free)': 'Function_Restored'})

# %%
smileon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40032 entries, 0 to 40031
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CallReportNum             40032 non-null  int64
#  1   CallerNum                 40032 non-null  int64
#  2   Last_Screen_Date          14892 non-null  object
#  3   Care_Provided             24849 non-null  object
#  4   Enroller_ID               32801 non-null  object
#  5   Treatment_Plan_Completed  17535 non-null  object
#  6   Treatment_Plan_Developed  17028 non-null  object
#  7   Function_Restored         14276 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 2.4+ MB

# %%
smileon.head()
# Out:
#    CallReportNum  CallerNum Last_Screen_Date  \
# 0       81381827    3859874              NaN
# 1       81379177    3859755              NaN
# 2       81377435    2518680              NaN
# 3       81375215    3231923              NaN
# 4       81373934         -1       11/25/2020
#
#                                        Care_Provided  \
# 0                                                NaN
# 1                                                NaN
# 2  5650 - Add tooth to existing partial denture - 30
# 3  No Code - Denture step Mandibular: may be used...
# 4                                                NaN
#
#                                          Enroller_ID Treatment_Plan_Completed  \
# 0  Matthew Walker Comprehensive Health Center Inc...                      NaN
# 1                                                NaN                      NaN
# 2          Friends in Need Health Center - Kingsport                      Yes
# ...

# %%
smileon.describe()
# Out:
#        CallReportNum     CallerNum
# count   4.003200e+04  4.003200e+04
# mean    6.811432e+07  2.827383e+06
# std     6.862238e+06  3.605287e+05
# min     5.319245e+07 -2.000000e+00
# 25%     6.291154e+07  2.567229e+06
# 50%     6.769168e+07  2.800698e+06
# 75%     7.248042e+07  2.999736e+06
# max     8.138183e+07  3.859874e+06

# %%
smileon = smileon[smileon.CallerNum != ((-1),(-2)) ]

# %%
smileon.shape
# Out:
# (39962, 8)

# %%
smileon.CallerNum.value_counts()
# Out:
#  2441776    36
#  2431132    31
#  2416076    29
#  2860770    28
#  2466994    28
#  2412580    26
#  3483924    25
#  2508895    25
#  2605896    25
#  2384974    24
#  2758336    23
#  2398755    23
#  2519897    23
#  2585132    23
#  2413871    23
#  2390065    23
#  2402037    22
#  2758373    22
#  3212379    22
#  2466431    22
#  2572538    22
#  2626906    22
#  2384932    22
#  2509118    22
#  2425664    22
#  2478100    22
#  2491028    21
#  2568307    21
#  2393460    21
#  2604689    21
#  2422239    21
#  2710754    21
#  2628089    21
#  2825704    21
#  2446699    21
#  2615950    21
#  2951481    20
#  2384949    20
#  2511808    20
#  2974096    20
#  2652999    20
#  2669784    20
#  2409767    20
#  3180577    20
#  2766987    20
#  2398657    20
#  2442290    20
#  2710403    20
#  2682296    20
#  2393897    19
#  2422345    19
#  2500180    19
#  2390783    19
#  2431051    19
#  2639063    19
#  2464232    19
#  2849688    19
#  2636008    19
# ...

# %%
smileon.Treatment_Plan_Developed.value_counts(ascending= False)
# Out:
# Yes    15928
# No      1095
# Name: Treatment_Plan_Developed, dtype: int64

# %%
smileon.Treatment_Plan_Completed.value_counts()
# Out:
# No     12431
# Yes     5103
# Name: Treatment_Plan_Completed, dtype: int64

# %%
smile_2441776 = smileon.loc[smileon['CallerNum'] == 2441776]

smile_2441776
# Out:
#        CallReportNum  CallerNum Last_Screen_Date  \
# 685         80878764    2441776        9/25/2018
# 1024        80784223    2441776        9/25/2018
# 3353        79037448    2441776        9/25/2018
# 3812        78220913    2441776         9/2/2020
# 3833        78698465    2441776        9/25/2018
# 5312        77631129    2441776        9/25/2018
# 5906        76991587    2441776        9/25/2018
# 6439        76991448    2441776        9/25/2018
# 11473       71557178    2441776        9/25/2018
# 14542       70184765    2441776        9/25/2018
# 15915       69739760    2441776        9/25/2018
# 17045       69171583    2441776        9/25/2018
# 18708       68129507    2441776        9/25/2018
# 19489       67757927    2441776        9/25/2018
# 21906       66789188    2441776        9/25/2018
# 24170       65850728    2441776        9/25/2018
# 26767       64563999    2441776        9/25/2018
# 28026       64343269    2441776        9/25/2018
# ...

# %% [markdown]
# Has the Smile On program been effective?

# %%
smileon.Function_Restored.value_counts()
# Out:
# No     8123
# Yes    6149
# Name: Function_Restored, dtype: int64

# %%
smileon.Treatment_Plan_Developed.value_counts()
# Out:
# Yes    15928
# No      1095
# Name: Treatment_Plan_Developed, dtype: int64

# %%
smileon.Treatment_Plan_Completed.value_counts()
# Out:
# No     12431
# Yes     5103
# Name: Treatment_Plan_Completed, dtype: int64

# %%
smileon.Enroller_ID.value_counts()
# Out:
# Interfaith Dental Clinic - Nashville                                                    5797
# Interfaith Dental Clinic - Murfreesboro                                                 3646
# Church Health Center - Memphis                                                          3581
# Matthew Walker Comprehensive Health Center Inc. - Nashville                             2516
# Interfaith Health Clinic of Knoxville - Knoxville                                       1822
# Karis Dental Clinic - Cleveland                                                         1809
# Friends in Need Health Center - Kingsport                                               1566
# Healing Hands Health Center - Bristol                                                   1346
# Keystone Dental Care Inc. - Johnson City                                                1031
# Christ Community Health Services- Hickory Hill                                           986
# ...
